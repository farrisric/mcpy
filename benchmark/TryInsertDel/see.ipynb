# %%
from ase.io import read
from ase.visualize import view
from ase.cluster import Octahedron
from ase.build import fcc111, molecule, bulk
from ase import Atoms
import numpy as np
import sys
from ase.io import read

# %%
xyz = read('Hybrid_GCMC.xyz', ':')
view(xyz)
# Out:
# <Popen: returncode: None args: ['/Users/emanuele/miniconda3/envs/mcpy/bin/py...>
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/emanuele/miniconda3/envs/mcpy/lib/python3.11/site-packages/ase/gui/pipe.py", line 32, in <module>
#     main()
#   File "/Users/emanuele/miniconda3/envs/mcpy/lib/python3.11/site-packages/ase/gui/pipe.py", line 28, in main
#     plt.show()
#   File "/Users/emanuele/miniconda3/envs/mcpy/lib/python3.11/site-packages/matplotlib/pyplot.py", line 614, in show
#     return _get_backend_mod().show(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/emanuele/miniconda3/envs/mcpy/lib/python3.11/site-packages/matplotlib_inline/backend_inline.py", line 90, in show
#     display(
#   File "/Users/emanuele/miniconda3/envs/mcpy/lib/python3.11/site-packages/IPython/core/display_functions.py", line 265, in display
#     print(*objs)
# ValueError: I/O operation on closed file.

# %%
atoms = Octahedron('Ag', 4, 1)
atoms.center(3)
box = atoms.get_cell()
volume_acc = box.volume - 4/3 * np.pi * (1.0**3) * len(atoms)
print(volume_acc, box.volume)
# Out:
# 2692.032604218116 2851.206631999999
